# %%
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
total = 0
num_5 = 0   # 5가 나온 횟수
n = 5000    # 주사위를 던진 횟수

for i in range(n):
    if np.random.randint(6)+1 == 5:
        num_5 += 1

    total += 1
    x.append(i)
    y.append(num_5/total)

plt.plot(x, y)
plt.plot(x, [1/6]*n, linestyle='dashed')    # 1/6을 점선으로 표시

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
total = 0
num_front = 0   # 동전 앞면이 위가 된 횟수
n = 5000    # 동전을 던진 횟수

for i in range(n):
    if np.random.randint(2) == 0:
        num_front += 1

    total += 1
    x.append(i)
    y.append(num_front/total)

plt.plot(x, y)
plt.plot(x, [1/2]*n, linestyle='dashed')    # 1/2을 점선으로 표시

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

# %%
# 평균값 구현

x = np.array([55, 45, 60, 40])

print(np.average(x))
# Out:
# 50.0

# %%
# 기대값 구현

p = np.array([0.8, 0.15, 0.05]) # 확률
x = np.array([100, 500, 1000])  # 값

print(np.sum(p*x))

# 기대값 = 평균 (같은 의미로 사용됨)
# Out:
# 205.0

# %%
p = np.array([0.75, 0.23, 0.02])
x = np.array([100, 500, 10000])

# 기댓값
print(np.sum(p*x))
# Out:
# 390.0

# %%
# 분산

x_1 = np.array([55, 45, 60, 40])
x_2 = np.array([51, 49, 52, 48])

print(np.var(x_1))
print(np.var(x_2))  # 분산이 더 작다
# Out:
# 62.5
# 2.5

# %%
# 표준편차

x_1 = np.array([55, 45, 60, 40])
x_2 = np.array([51, 49, 52, 48])

print(np.std(x_1))
print(np.std(x_2))
# Out:
# 7.905694150420948
# 1.5811388300841898

# %%
x = np.array([51, 49, 52, 48])

# 분산과 표준편차
print(np.var(x))
print(np.std(x))
# Out:
# 2.5
# 1.5811388300841898

# %%
# 정규분포곡선

def pdf(x, mu, sigma):   # mu: 평균, sigma: 표준편차
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2))

x = np.linspace(-5, 5)
y_1 = pdf(x, 0.0, 0.5)
y_2 = pdf(x, 0.0, 1.0)
y_3 = pdf(x, 0.0, 2.0)

plt.plot(x, y_1, label='σ: 0.5', linestyle = 'dashed')
plt.plot(x, y_2, label='σ: 1.0', linestyle = 'solid')
plt.plot(x, y_3, label='σ: 2.0', linestyle = 'dashdot')
plt.legend()

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

# %%
s = np.random.normal(0, 1, 10000)   # 평균 0, 표준편차 1, 10000개

# 히스토그램
plt.hist(s, bins=25)    # bins는 기둥의 수

plt.xlabel('x', size=14)
plt.grid()
plt.show()

# %%
# 거듭제곱법칙

def power_func(x, c, k):
    return c*x**(-k)

x = np.linspace(1, 5)
y_1 = power_func(x, 1.0, 1.0)   # c:1.0 k:1.0
y_2 = power_func(x, 1.0, 2.0)   # c:1.0 k:2.0
y_3 = power_func(x, 1.0, 4.0)   # c:1.0 k:4.0

plt.plot(x, y_1, label = 'k=1.0', linestyle='dashed')
plt.plot(x, y_2, label = 'k=2.0', linestyle='solid')
plt.plot(x, y_3, label = 'k=4.0', linestyle='dashdot')
plt.legend()

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

# %%
# 파레토 분포를 따르는 난수

s = np.random.pareto(4, 1000)   # a=4, m=1, 1000개

# 히스토그램
plt.hist(s, bins=25)
plt.xlabel('x', size=14)
plt.grid()
plt.show()

# %%
s = np.random.normal(0, 1, 1000)

# 히스토그램
plt.hist(s, bins=25)

plt.xlabel('x', size=14)
plt.grid()
plt.show()

# %%
# 공분산과 데이터의 경향

x = np.array([50, 70, 40, 60, 80])
y = np.array([60, 80, 50, 50, 70])
z = np.array([60, 40, 60, 40, 30])

cov_xy = np.average((x-np.average(x))*(y-np.average(y)))
print('cov_xy: ',cov_xy)

cov_xz = np.average((x-np.average(x))*(z-np.average(z)))
print('cov_xz: ',cov_xz)

plt.scatter(x, y, marker='o', label='xy', s=40)
plt.scatter(x, z, marker='x', label='xz', s=60)
plt.legend()

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()
# Out:
# cov_xy:  120.0
# cov_xz:  -160.0

# %%
def show_cov(cov):
    print('--- Covariance:', cov,' ---')
    average = np.array([0, 0])  # x와 y 각각의 평균
    cov_matrix = np.array([[1, cov],    # 공분산을 행렬로 지정
                           [cov, 1]])
    
    # 공분산으로부터 페어 데이터를 3000짝 생성.
    # data는 (3000, 2)의 형상의 행렬이 됨
    data = np.random.multivariate_normal(average, cov_matrix, 3000)
    x = data[:, 0]
    y = data[:, 1]

    plt.scatter(x, y, marker='x', s=20)

    plt.xlabel('x', size=14)
    plt.ylabel('y', size=14)
    plt.grid()
    plt.show()

show_cov(0.6)
show_cov(0.0)
show_cov(-0.6)
# Out:
# --- Covariance: 0.6  ---
# --- Covariance: 0.0  ---
# --- Covariance: -0.6  ---

# %%
x = np.array([30, 70, 40, 60, 90])
y = np.array([20, 60, 50, 40, 80])

cov_xy = np.average((x-np.average(x))*(y-np.average(y)))
print('cov_xy: ',cov_xy)

plt.scatter(x, y, marker='o', label='xy', s=40)
plt.legend()

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()
# Out:
# cov_xy:  380.0

# %%
x = np.array([50, 70, 40, 60, 80])
y = np.array([60, 80, 50, 50, 70])

print('--- corrcoef() 함수를 사용 ---')
print(np.corrcoef(x, y))

print()

print('--- 공분산과 표준편차로부터 구한다 ---')
cov_xy = np.average((x-np.average(x))*(y-np.average(y)))
print(cov_xy/(np.std(x)*np.std(y)))

plt.scatter(x,y)

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()
# Out:
# --- corrcoef() 함수를 사용 ---
# [[1.         0.72760688]
#  [0.72760688 1.        ]]
#
# --- 공분산과 표준편차로부터 구한다 ---
# 0.7276068751089989

# %%
# 우도가 작은 케이스

x_data = np.array([2.4, 1.2, 3.5, 2.1, 4.7])
y_data = np.zeros(5)

mu = 0
sigma = 1

def pdf(x, mu, sigma):   
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2)) # 확률밀도함수

x_pdf = np.linspace(-5, 5)
y_pdf = pdf(x_pdf, mu, sigma)

plt.scatter(x_data, y_data)
plt.plot(x_pdf, y_pdf)

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

print('--- 우도 ---')
print(np.prod(pdf(x_data, mu, sigma)))

print('--- 대수우도 ---')
print(np.sum(np.log(pdf(x_data, mu, sigma))))
# Out:
# --- 우도 ---
# 1.0632480805734735e-12
# --- 대수우도 ---
# -27.569692666023364

# %%
# 우도가 큰 케이스

x_data = np.array([2.4, 1.2, 3.5, 2.1, 4.7])
y_data = np.zeros(5)

mu = np.average(x_data)
sigma = np.std(x_data)

def pdf(x, mu, sigma):   
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2)) # 확률밀도함수

x_pdf = np.linspace(-3, 7)
y_pdf = pdf(x_pdf, mu, sigma)

plt.scatter(x_data, y_data)
plt.plot(x_pdf, y_pdf)

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

print('--- 우도 ---')
print(np.prod(pdf(x_data, mu, sigma)))

print('--- 대수우도 ---')
print(np.sum(np.log(pdf(x_data, mu, sigma))))
# Out:
# --- 우도 ---
# 0.0003211757807192693
# --- 대수우도 ---
# -8.043521981227514

# %%
x_data = np.array([2.4, 1.2, 3.5, 2.1, 4.7])

mu = np.average(x_data)
sigma = np.std(x_data)

def pdf(x, mu, sigma):   
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2)) # 확률밀도함수

def log_likehood(p):
    return np.sum(np.log(p))

x_sigma = np.linspace(0.5, 8)   # 가로축에 사용하는 표준편차
y_loglike = []  # 세로축에 사용하는 대수우도

for s in x_sigma:
    log_like = log_likehood(pdf(x_data, mu, s))
    y_loglike.append(log_like)  # 대수우도를 세로축에 추가

plt.plot(x_sigma, np.array(y_loglike))
plt.plot([sigma, sigma], [min(y_loglike), max(y_loglike)], linestyle="dashed")  # 데이터의 표준편차의 위치에 세로선을 긋는다

plt.xlabel('x_sigma', size=14)
plt.ylabel('y_loglike', size=14)
plt.grid()
plt.show()

# %%
x_data = np.array([2.4, 1.2, 3.5, 2.1, 4.7])
y_data = np.zeros(5)

mu = 4.0
sigma = 0.8

def pdf(x, mu, sigma):   
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2)) # 확률밀도함수

x_pdf = np.linspace(-1, 9)
y_pdf = pdf(x_pdf, mu, sigma)

plt.scatter(x_data, y_data)
plt.plot(x_pdf, y_pdf)

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

print('--- 우도 ---')
print(np.prod(pdf(x_data, mu, sigma)))

print('--- 대수우도 ---')
print(np.sum(np.log(pdf(x_data, mu, sigma))))
# Out:
# --- 우도 ---
# 3.0516524826983536e-07
# --- 대수우도 ---
# -15.002412409452313
