# %%
import numpy as np
import matplotlib.pyplot as plt

def my_func(x):
    return 3*x**2 + 4*x - 5

def my_func_dif(x): # 도함수
    return 6*x + 4

x = np.linspace(-3 ,3)
y = my_func(x)

a = 1
y_t = my_func_dif(a)*x + my_func(a) - my_func_dif(a)*a  # x=1일 때의 접선, 접선 식을 사용

plt.plot(x, y, label='y')
plt.plot(x, y_t, label='y_t')
plt.legend()

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_func(x):
    return -2*x**2 + x + 3

def my_func_dif(x): # 도함수
    return -4*x + 1

x = np.linspace(-3 ,3)
y = my_func(x)

a = 1
y_t = my_func_dif(a)*x + my_func(a) - my_func_dif(a)*a  # x=1일 때의 접선, 접선 식을 사용

plt.plot(x, y, label='y')
plt.plot(x, y_t, label='y_t')
plt.legend()

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.grid()
plt.show()

# %% [markdown]
# $$y = (x^2 + 4x + 1)^4 -> 미분하면 $$
# $$-> y = u^4$$
# $$-> y = 4u^3(2x + 4)$$
# $$-> y = 4(x^2 + 4x + 1)^3(2x + 4)$$

# %% [markdown]
# $$f(x, y) = 2x^3 + 4x^2y + xy^2 - 4y^2 -> x에\;대해\;편미분하면$$
# $$-> 6x^2 + 8xy + y^2$$
# $$f(x, y) = 2x^3 + 4x^2y + xy^2 - 4y^2 -> y에\;대해\;편미분하면$$
# $$-> 4x^2 + 2xy - 8y$$

# %% [markdown]
# $$f(x, y) = 2x^3 + 4x^2y + xy^2 - 4y^2 -> 전미분하면$$
# $$x에\;대한\;편미분\;-> 6x^2 + 8xy + y^2$$
# $$y에\;대한\;편미분\;-> 4x^2 + 2xy - 8y^2$$
# $$전미분한\;식은\;-> dz = (6x^2 + 8xy + y^2)dx + (4x^2 + 2xy - 8y^2)dy$$
